# %%
import sys
import os
import random
import pandas as pd
sys.path.append(os.path.abspath('../scripts'))
sys.path.append(os.path.abspath('../src')) 

from load_data import DataLoader
import path 
from EDA import EDA
from visualizations import visualize

# %%
# Loading and reading text file using pandas
folder_path = path.get_path()
data_load = DataLoader(folder_path)
df = data_load.load_txt_data()

# %%
df.head()
# Out:
#   ,UnderwrittenCoverID,PolicyID,TransactionMonth,IsVATRegistered,Citizenship,LegalType,Title,Language,Bank,AccountType,MaritalStatus,Gender,Country,Province,PostalCode,MainCrestaZone,SubCrestaZone,ItemType,mmcode,VehicleType,RegistrationYear,make,Model,Cylinders,cubiccapacity,kilowatts,bodytype,NumberOfDoors,VehicleIntroDate,CustomValueEstimate,AlarmImmobiliser,TrackingDevice,CapitalOutstanding,NewVehicle,WrittenOff,Rebuilt,Converted,CrossBorder,NumberOfVehiclesInFleet,SumInsured,TermFrequency,CalculatedPremiumPerTerm,ExcessSelected,CoverCategory,CoverType,CoverGroup,Section,Product,StatutoryClass,StatutoryRiskType,TotalPremium,TotalClaims
# 0  0,145249,12827,3/1/2015 0:00,TRUE,  ,Close Cor...
# 1  1,145249,12827,5/1/2015 0:00,TRUE,  ,Close Cor...
# 2  2,145249,12827,7/1/2015 0:00,TRUE,  ,Close Cor...
# 3  3,145255,12827,5/1/2015 0:00,TRUE,  ,Close Cor...
# 4  4,145255,12827,7/1/2015 0:00,TRUE,  ,Close Cor...

# %%
# write the text file to csv file for more readebility and ease of use
df.to_csv('../Data/alphacare_car_insurance_data.csv')

# %%
df1 = pd.read_csv("../Data/alphacare_car_insurance_data.csv", low_memory=False)

# %% [markdown]
# ## Data Summarization
# #### 1. Data Overview

# %%
print("\nFirst 5 rows:")
print(df1.head())
# Out:
# First 5 rows:
#    Unnamed: 0  UnderwrittenCoverID  PolicyID TransactionMonth  \
# 0           0               145249     12827    3/1/2015 0:00
# 1           1               145249     12827    5/1/2015 0:00
# 2           2               145249     12827    7/1/2015 0:00
# 3           3               145255     12827    5/1/2015 0:00
# 4           4               145255     12827    7/1/2015 0:00
#
#    IsVATRegistered Citizenship          LegalType Title Language  \
# 0             True              Close Corporation    Mr  English
# 1             True              Close Corporation    Mr  English
# 2             True              Close Corporation    Mr  English
# 3             True              Close Corporation    Mr  English
# 4             True              Close Corporation    Mr  English
#
#                   Bank  ...                    ExcessSelected CoverCategory  \
# 0  First National Bank  ...             Mobility - Windscreen    Windscreen
# 1  First National Bank  ...             Mobility - Windscreen    Windscreen
# 2  First National Bank  ...             Mobility - Windscreen    Windscreen
# 3  First National Bank  ...  Mobility - Metered Taxis - R2000    Own damage
# 4  First National Bank  ...  Mobility - Metered Taxis - R2000    Own damage
#
#     CoverType            CoverGroup              Section  \
# 0  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3  Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4  Own Damage  Comprehensive - Taxi  Motor Comprehensive
#
#                            Product StatutoryClass StatutoryRiskType  \
# 0  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 1  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 2  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 3  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 4  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
#
#   TotalPremium  TotalClaims
# 0    21.929825          0.0
# 1    21.929825          0.0
# 2     0.000000          0.0
# 3   512.848070          0.0
# 4     0.000000          0.0
#
# [5 rows x 53 columns]

# %%
# print the infomation of the data
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   Unnamed: 0                1000098 non-null  int64
#  1   UnderwrittenCoverID       1000098 non-null  int64
#  2   PolicyID                  1000098 non-null  int64
#  3   TransactionMonth          1000098 non-null  object
#  4   IsVATRegistered           1000098 non-null  bool
#  5   Citizenship               1000098 non-null  object
#  6   LegalType                 1000098 non-null  object
#  7   Title                     1000098 non-null  object
#  8   Language                  1000098 non-null  object
#  9   Bank                      854137 non-null   object
#  10  AccountType               959866 non-null   object
#  11  MaritalStatus             991839 non-null   object
#  12  Gender                    990562 non-null   object
#  13  Country                   1000098 non-null  object
#  14  Province                  1000098 non-null  object
#  15  PostalCode                1000098 non-null  int64
#  16  MainCrestaZone            1000098 non-null  object
#  17  SubCrestaZone             1000098 non-null  object
#  18  ItemType                  1000098 non-null  object
#  19  mmcode                    999546 non-null   float64
#  20  VehicleType               999546 non-null   object
#  21  RegistrationYear          1000098 non-null  int64
#  22  make                      999546 non-null   object
#  23  Model                     999546 non-null   object
#  24  Cylinders                 999546 non-null   float64
#  25  cubiccapacity             999546 non-null   float64
#  26  kilowatts                 999546 non-null   float64
#  27  bodytype                  999546 non-null   object
#  28  NumberOfDoors             999546 non-null   float64
#  29  VehicleIntroDate          999546 non-null   object
#  30  CustomValueEstimate       220456 non-null   float64
#  31  AlarmImmobiliser          1000098 non-null  object
#  32  TrackingDevice            1000098 non-null  object
#  33  CapitalOutstanding        1000096 non-null  object
#  34  NewVehicle                846803 non-null   object
#  35  WrittenOff                358197 non-null   object
#  36  Rebuilt                   358197 non-null   object
#  37  Converted                 358197 non-null   object
#  38  CrossBorder               698 non-null      object
#  39  NumberOfVehiclesInFleet   0 non-null        float64
#  40  SumInsured                1000098 non-null  float64
#  41  TermFrequency             1000098 non-null  object
#  42  CalculatedPremiumPerTerm  1000098 non-null  float64
#  43  ExcessSelected            1000098 non-null  object
#  44  CoverCategory             1000098 non-null  object
#  45  CoverType                 1000098 non-null  object
#  46  CoverGroup                1000098 non-null  object
#  47  Section                   1000098 non-null  object
#  48  Product                   1000098 non-null  object
#  49  StatutoryClass            1000098 non-null  object
#  50  StatutoryRiskType         1000098 non-null  object
#  51  TotalPremium              1000098 non-null  float64
#  52  TotalClaims               1000098 non-null  float64
# dtypes: bool(1), float64(11), int64(5), object(36)
# memory usage: 397.7+ MB

# %%
# Statistical distribution of attribuets
df1.describe()
# Out:
#          Unnamed: 0  UnderwrittenCoverID      PolicyID    PostalCode  \
# count  1.000098e+06         1.000098e+06  1.000098e+06  1.000098e+06
# mean   5.000485e+05         1.048175e+05  7.956682e+03  3.020601e+03
# std    2.887036e+05         6.329371e+04  5.290039e+03  2.649854e+03
# min    0.000000e+00         1.000000e+00  1.400000e+01  1.000000e+00
# 25%    2.500242e+05         5.514300e+04  4.500000e+03  8.270000e+02
# 50%    5.000485e+05         9.408300e+04  7.071000e+03  2.000000e+03
# 75%    7.500728e+05         1.391900e+05  1.107700e+04  4.180000e+03
# max    1.000097e+06         3.011750e+05  2.324600e+04  9.870000e+03
#
#              mmcode  RegistrationYear      Cylinders  cubiccapacity  \
# count  9.995460e+05      1.000098e+06  999546.000000  999546.000000
# mean   5.487770e+07      2.010225e+03       4.046642    2466.743258
# std    1.360381e+07      3.261391e+00       0.294020     442.800640
# min    4.041200e+06      1.987000e+03       0.000000       0.000000
# 25%    6.005692e+07      2.008000e+03       4.000000    2237.000000
# 50%    6.005842e+07      2.011000e+03       4.000000    2694.000000
# 75%    6.005842e+07      2.013000e+03       4.000000    2694.000000
# max    6.506535e+07      2.015000e+03      10.000000   12880.000000
#
#            kilowatts  NumberOfDoors  CustomValueEstimate  \
# count  999546.000000  999546.000000         2.204560e+05
# mean       97.207919       4.019250         2.255311e+05
# std        19.393256       0.468314         5.645157e+05
# min         0.000000       0.000000         2.000000e+04
# 25%        75.000000       4.000000         1.350000e+05
# 50%       111.000000       4.000000         2.200000e+05
# 75%       111.000000       4.000000         2.800000e+05
# max       309.000000       6.000000         2.655000e+07
#
#        NumberOfVehiclesInFleet    SumInsured  CalculatedPremiumPerTerm  \
# count                      0.0  1.000098e+06              1.000098e+06
# mean                       NaN  6.041727e+05              1.178757e+02
# std                        NaN  1.508332e+06              3.997017e+02
# min                        NaN  1.000000e-02              0.000000e+00
# 25%                        NaN  5.000000e+03              3.224800e+00
# 50%                        NaN  7.500000e+03              8.436900e+00
# 75%                        NaN  2.500000e+05              9.000000e+01
# max                        NaN  1.263620e+07              7.442217e+04
#
#        TotalPremium   TotalClaims
# count  1.000098e+06  1.000098e+06
# mean   6.190550e+01  6.486119e+01
# std    2.302845e+02  2.384075e+03
# min   -7.825768e+02 -1.200241e+04
# 25%    0.000000e+00  0.000000e+00
# 50%    2.178333e+00  0.000000e+00
# 75%    2.192982e+01  0.000000e+00
# max    6.528260e+04  3.930921e+05

# %%
# Select numerical columns
num_cols = df1.select_dtypes(include=['number'])
# Compute variability metrics
variability_metrics = pd.DataFrame({
    "Mean": num_cols.mean(),
    "Standard Deviation": num_cols.std(),
    "Variance": num_cols.var(),
    "Range": num_cols.max() - num_cols.min(),
    "IQR": num_cols.quantile(0.75) - num_cols.quantile(0.25)
})

# Display variability statistics
print(variability_metrics)
# Out:
#                                   Mean  Standard Deviation      Variance  \
# Unnamed: 0                5.000485e+05        2.887036e+05  8.334975e+10
# UnderwrittenCoverID       1.048175e+05        6.329371e+04  4.006094e+09
# PolicyID                  7.956682e+03        5.290039e+03  2.798451e+07
# PostalCode                3.020601e+03        2.649854e+03  7.021728e+06
# mmcode                    5.487770e+07        1.360381e+07  1.850635e+14
# RegistrationYear          2.010225e+03        3.261391e+00  1.063667e+01
# Cylinders                 4.046642e+00        2.940201e-01  8.644783e-02
# cubiccapacity             2.466743e+03        4.428006e+02  1.960724e+05
# kilowatts                 9.720792e+01        1.939326e+01  3.760984e+02
# NumberOfDoors             4.019250e+00        4.683144e-01  2.193184e-01
# CustomValueEstimate       2.255311e+05        5.645157e+05  3.186780e+11
# NumberOfVehiclesInFleet            NaN                 NaN           NaN
# SumInsured                6.041727e+05        1.508332e+06  2.275065e+12
# CalculatedPremiumPerTerm  1.178757e+02        3.997017e+02  1.597615e+05
# TotalPremium              6.190550e+01        2.302845e+02  5.303096e+04
# TotalClaims               6.486119e+01        2.384075e+03  5.683812e+06
#
#                                  Range            IQR
# Unnamed: 0                1.000097e+06  500048.500000
# UnderwrittenCoverID       3.011740e+05   84047.000000
# PolicyID                  2.323200e+04    6577.000000
# PostalCode                9.869000e+03    3353.000000
# mmcode                    6.102415e+07    1493.000000
# RegistrationYear          2.800000e+01       5.000000
# Cylinders                 1.000000e+01       0.000000
# cubiccapacity             1.288000e+04     457.000000
# kilowatts                 3.090000e+02      36.000000
# NumberOfDoors             6.000000e+00       0.000000
# CustomValueEstimate       2.653000e+07  145000.000000
# NumberOfVehiclesInFleet            NaN            NaN
# SumInsured                1.263620e+07  245000.000000
# CalculatedPremiumPerTerm  7.442217e+04      86.775200
# TotalPremium              6.606518e+04      21.929825
# TotalClaims               4.050945e+05       0.000000

# %%
# Check unique values for categorical variables
categorical_cols = df1.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols:
    print(f"\nColumn: {col}")
    print(df1[col].unique()[:10])
# Out:
# Column: TransactionMonth
# ['3/1/2015 0:00' '5/1/2015 0:00' '7/1/2015 0:00' '1/1/2015 0:00'
#  '4/1/2015 0:00' '6/1/2015 0:00' '8/1/2015 0:00' '2/1/2015 0:00'
#  '12/1/2014 0:00' '11/1/2014 0:00']
#
# Column: Citizenship
# ['  ' 'AF' 'ZA' 'ZW']
#
# Column: LegalType
# ['Close Corporation' 'Individual' 'Partnership' 'Private company'
#  'Public company' 'Sole proprieter']
#
# Column: Title
# ['Mr' 'Dr' 'Miss' 'Mrs' 'Ms']
#
# Column: Language
# ['English']
#
# Column: Bank
# ['First National Bank' 'Standard Bank' nan 'ABSA Bank' 'Capitec Bank'
#  'Nedbank' 'FirstRand Bank' 'Investec Bank' 'Ithala Bank' 'Old Mutual']
#
# Column: AccountType
# ['Current account' 'Savings account' nan 'Transmission account']
#
# Column: MaritalStatus
# ['Not specified' 'Married' 'Single' nan]
#
# Column: Gender
# ['Not specified' 'Male' 'Female' nan]
#
# Column: Country
# ['South Africa']
#
# Column: Province
# ['Gauteng' 'KwaZulu-Natal' 'Mpumalanga' 'Eastern Cape' 'Western Cape'
#  'Limpopo' 'North West' 'Free State' 'Northern Cape']
#
# Column: MainCrestaZone
# ['Rand East' 'Transvaal (all except Pretoria)' 'Johannesburg'
#  'Natal (Durban)' 'Tembu 2, Cape Mid 2, Cape Mid West, Tembu 1'
#  'Transvaal (Pretoria)' 'Natal' 'Cape Province (Cape Town)'
#  'Langkloof, Coast 2, Coast 1'
#  'Cape Province (East and North of Cape Town)']
#
# Column: SubCrestaZone
# ['Rand East' 'Transvaal South' 'Johannesburg' 'Durban'
#  'Transvaal South East' 'Cape Mid West' 'Pretoria' 'Rand West'
#  'North Coast' 'Cape Town']
#
# Column: ItemType
# ['Mobility - Motor']
#
# Column: VehicleType
# ['Passenger Vehicle' 'Medium Commercial' 'Heavy Commercial'
#  'Light Commercial' 'Bus' nan]
#
# Column: make
# ['MERCEDES-BENZ' 'VOLKSWAGEN' 'RENAULT' 'FORD' 'BMW' 'AUDI' 'VOLVO'
#  'PROTON' 'TOYOTA' 'NISSAN/DATSUN                      ']
#
# Column: Model
# ['E 240' 'TOUAREG 5.0 V10 TDI TIP' 'SCENIC 1.9 dCi EXPRESSION'
#  'TERRITORY 4.0i GHIA AWD A/T' '320i (E90)' 'FIESTA 1.6 SPORT 5Dr'
#  'A4 1.8T ATTRACTION (B8)' 'S40 T5 A/T' 'SAVVY 1.2 SPORT' 'GEN 2 1.6 GL']
#
# Column: bodytype
# ['S/D' 'SUV' 'MPV' 'H/B' 'P/V' 'B/S' 'S/W' 'C/C' 'D/C' 'D/S']
#
# Column: VehicleIntroDate
# ['Jun-02' 'Mar-04' 'Feb-03' 'Jun-05' '11/1/2008 0:00' 'Nov-10'
#  '8/1/2008 0:00' 'May-04' 'Feb-06' 'Aug-05']
#
# Column: AlarmImmobiliser
# ['Yes' 'No']
#
# Column: TrackingDevice
# ['No' 'Yes']
#
# Column: CapitalOutstanding
# ['119300' '161000' '52700' '127300' '146800' '140400' '208800' '86300'
#  '48100' '62400']
#
# Column: NewVehicle
# ['More than 6 months' nan 'Less than 6 months']
#
# Column: WrittenOff
# [nan 'No' 'Yes']
#
# Column: Rebuilt
# [nan 'No' 'Yes']
#
# Column: Converted
# [nan 'No' 'Yes']
#
# Column: CrossBorder
# [nan 'No']
#
# Column: TermFrequency
# ['Monthly' 'Annual']
#
# Column: ExcessSelected
# ['Mobility - Windscreen' 'Mobility - Metered Taxis - R2000' 'No excess'
#  'Mobility - Taxi with value more than R100 000 - R5 000'
#  'Mobility - Windscreen (Feb2015)'
#  'Mobility - Taxi with value more than R100 000 - R10 000'
#  'Mobility - Taxi with value less than R100 000 - R3 000'
#  'Mobility - Taxi with value more than R100 000 - R5 000 (April)'
#  'Mobility - Metered Taxis - R5000' 'Mobility - R250']
#
# Column: CoverCategory
# ['Windscreen' 'Own damage' 'Third Party' 'Passenger Liability'
#  'Signage and Vehicle Wraps' 'Keys and Alarms'
#  'Cleaning and Removal of Accident Debris' 'Emergency Charges'
#  'Credit Protection' 'Roadside Assistance']
#
# Column: CoverType
# ['Windscreen' 'Own Damage' 'Third Party' 'Passenger Liability'
#  'Signage and Vehicle Wraps' 'Keys and Alarms'
#  'Cleaning and Removal of Accident Debris' 'Emergency Charges'
#  'Credit Protection' 'Roadside Assistance']
#
# Column: CoverGroup
# ['Comprehensive - Taxi' 'Credit Protection' 'Accidental Death'
#  'Basic Excess Waiver' 'Income Protector' 'Deposit Cover'
#  'Standalone passenger liability' 'Baggage/Luggage'
#  'Asset Value Preserver' 'Cash Takings']
#
# Column: Section
# ['Motor Comprehensive' 'Credit Protection' 'Optional Extended Covers'
#  'Standalone passenger liability'
#  'Third party or third party, fire and theft only']
#
# Column: Product
# ['Mobility Metered Taxis: Monthly' 'Mobility Commercial Cover: Monthly'
#  'Standalone Passenger Liability' 'Bridge Taxi Finance: Monthly']
#
# Column: StatutoryClass
# ['Commercial']
#
# Column: StatutoryRiskType
# ['IFRS Constant']

# %% [markdown]
# ## Data Quality Assessment:

# %%
# Check missing values
missing_values = df1.isnull().sum()
missing_percentage = (df1.isnull().sum() / len(df1)) * 100

# Display columns with missing values  : missing_percent.map('{:.2f} %'.format)
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage.map('{:.2f}%'.format)})
print(missing_data[missing_data["Missing Values"] > 0])
# Out:
#                          Missing Values Percentage
# Bank                             145961     14.59%
# AccountType                       40232      4.02%
# MaritalStatus                      8259      0.83%
# Gender                             9536      0.95%
# mmcode                              552      0.06%
# VehicleType                         552      0.06%
# make                                552      0.06%
# Model                               552      0.06%
# Cylinders                           552      0.06%
# cubiccapacity                       552      0.06%
# kilowatts                           552      0.06%
# bodytype                            552      0.06%
# NumberOfDoors                       552      0.06%
# VehicleIntroDate                    552      0.06%
# CustomValueEstimate              779642     77.96%
# CapitalOutstanding                    2      0.00%
# NewVehicle                       153295     15.33%
# WrittenOff                       641901     64.18%
# Rebuilt                          641901     64.18%
# Converted                        641901     64.18%
# CrossBorder                      999400     99.93%
# NumberOfVehiclesInFleet         1000098    100.00%

# %%
edas =EDA(df1)

# %%
# Calculates overall and group-wise (Province, VehicleType, Gender) loss ratios
print("Calculates overall and group-wise (Province, VehicleType, Gender) loss ratios")
edas.compute_loss_ratio_stats()
# Out:
# Calculates overall and group-wise (Province, VehicleType, Gender) loss ratios
# (np.float64(1.0020980621762794),
#                  TotalClaims  TotalPremium  LossRatio
#  Province
#  Eastern Cape   1.346308e+06  2.140303e+06   0.629027
#  Free State     2.659749e+05  5.213632e+05   0.510153
#  Gauteng        2.798127e+07  2.405487e+07   1.163227
#  KwaZulu-Natal  1.352635e+07  1.323578e+07   1.021953
#  Limpopo        9.918930e+05  1.537324e+06   0.645207
#  Mpumalanga     2.035792e+06  2.836292e+06   0.717765
#  North West     5.593723e+06  7.490508e+06   0.746775
#  Northern Cape  8.949051e+04  3.165581e+05   0.282699
#  Western Cape   1.024226e+07  9.810107e+06   1.044052,
#                      TotalClaims  TotalPremium  LossRatio
#  VehicleType
#  Bus                0.000000e+00  5.824474e+04   0.000000
#  Heavy Commercial   7.432425e+05  4.609479e+05   1.612422
#  Light Commercial   6.045250e+04  2.604975e+05   0.232066
#  Medium Commercial  4.032212e+06  3.922840e+06   1.027881
#  Passenger Vehicle  5.668048e+07  5.667341e+07   1.000125,
#                  TotalClaims  TotalPremium  LossRatio
#  Gender
#  Female         2.472774e+05  3.044806e+05   0.812129
#  Male           1.242916e+06  1.606618e+06   0.773623
#  Not specified  6.007638e+07  5.920782e+07   1.014670)

# %%
print("Visualizes loss ratio distributions using bar charts")
edas.plot_loss_ratios("Province")
# Out:
# Visualizes loss ratio distributions using bar charts

# %%
edas.plot_loss_ratios("VehicleType")

# %%
edas.plot_loss_ratios("Gender")

# %%
edas.plot_loss_ratios("MaritalStatus")

# %%
edas.outliers_distribution(["TotalClaims", "CustomValueEstimate"])
# Out:
# {'TotalClaims': {'summary': count    1.000098e+06
#   mean     6.486119e+01
#   std      2.384075e+03
#   min     -1.200241e+04
#   25%      0.000000e+00
#   50%      0.000000e+00
#   75%      0.000000e+00
#   max      3.930921e+05
#   Name: TotalClaims, dtype: float64,
#   'outlier_count': 2793,
#   'outlier_percentage': 0.27927263128213436,
#   'upper_bound': np.float64(0.0),
#   'lower_bound': np.float64(0.0)},
#  'CustomValueEstimate': {'summary': count    2.204560e+05
#   mean     2.255311e+05
#   std      5.645157e+05
#   min      2.000000e+04
#   25%      1.350000e+05
#   50%      2.200000e+05
#   75%      2.800000e+05
#   max      2.655000e+07
#   Name: CustomValueEstimate, dtype: float64,
#   'outlier_count': 1785,
#   'outlier_percentage': 0.178482508714146,
#   'upper_bound': np.float64(497500.0),
#   'lower_bound': np.float64(-82500.0)}}

# %% [markdown]
# #### Claim Frequency: Number of claims per month.
#
# #### Claim Severity: Average claim amount per month = TotalClaims / number of claims.

# %%
edas.preprocess_transaction_month()
# Out:
#          Unnamed: 0  UnderwrittenCoverID  PolicyID TransactionMonth  \
# 0                 0               145249     12827       2015-03-01
# 1                 1               145249     12827       2015-05-01
# 2                 2               145249     12827       2015-07-01
# 3                 3               145255     12827       2015-05-01
# 4                 4               145255     12827       2015-07-01
# ...             ...                  ...       ...              ...
# 1000093     1000093                31520       389       2015-04-01
# 1000094     1000094                31520       389       2015-06-01
# 1000095     1000095                31520       389       2015-08-01
# 1000096     1000096                31519       389       2014-07-01
# 1000097     1000097                31519       389       2015-02-01
#
#          IsVATRegistered Citizenship          LegalType Title Language  \
# 0                   True              Close Corporation    Mr  English
# 1                   True              Close Corporation    Mr  English
# 2                   True              Close Corporation    Mr  English
# 3                   True              Close Corporation    Mr  English
# 4                   True              Close Corporation    Mr  English
# ...                  ...         ...                ...   ...      ...
# 1000093            False          ZW         Individual    Mr  English
# 1000094            False          ZW         Individual    Mr  English
# 1000095            False          ZW         Individual    Mr  English
# 1000096            False          ZW         Individual    Mr  English
# 1000097            False          ZW         Individual    Mr  English
#
#                         Bank  ...                    ExcessSelected  \
# 0        First National Bank  ...             Mobility - Windscreen
# 1        First National Bank  ...             Mobility - Windscreen
# 2        First National Bank  ...             Mobility - Windscreen
# 3        First National Bank  ...  Mobility - Metered Taxis - R2000
# 4        First National Bank  ...  Mobility - Metered Taxis - R2000
# ...                      ...  ...                               ...
# 1000093            ABSA Bank  ...                         No excess
# 1000094            ABSA Bank  ...                         No excess
# 1000095            ABSA Bank  ...                         No excess
# 1000096            ABSA Bank  ...                         No excess
# 1000097            ABSA Bank  ...                         No excess
#
#                CoverCategory            CoverType            CoverGroup  \
# 0                 Windscreen           Windscreen  Comprehensive - Taxi
# 1                 Windscreen           Windscreen  Comprehensive - Taxi
# 2                 Windscreen           Windscreen  Comprehensive - Taxi
# 3                 Own damage           Own Damage  Comprehensive - Taxi
# 4                 Own damage           Own Damage  Comprehensive - Taxi
# ...                      ...                  ...                   ...
# 1000093          Third Party          Third Party  Comprehensive - Taxi
# 1000094          Third Party          Third Party  Comprehensive - Taxi
# 1000095          Third Party          Third Party  Comprehensive - Taxi
# 1000096  Passenger Liability  Passenger Liability  Comprehensive - Taxi
# 1000097  Passenger Liability  Passenger Liability  Comprehensive - Taxi
#
#                      Section                             Product  \
# 0        Motor Comprehensive     Mobility Metered Taxis: Monthly
# 1        Motor Comprehensive     Mobility Metered Taxis: Monthly
# 2        Motor Comprehensive     Mobility Metered Taxis: Monthly
# 3        Motor Comprehensive     Mobility Metered Taxis: Monthly
# 4        Motor Comprehensive     Mobility Metered Taxis: Monthly
# ...                      ...                                 ...
# 1000093  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 1000094  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 1000095  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 1000096  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 1000097  Motor Comprehensive  Mobility Commercial Cover: Monthly
#
#         StatutoryClass StatutoryRiskType TotalPremium  TotalClaims
# 0           Commercial     IFRS Constant    21.929825          0.0
# 1           Commercial     IFRS Constant    21.929825          0.0
# 2           Commercial     IFRS Constant     0.000000          0.0
# 3           Commercial     IFRS Constant   512.848070          0.0
# 4           Commercial     IFRS Constant     0.000000          0.0
# ...                ...               ...          ...          ...
# 1000093     Commercial     IFRS Constant   347.235175          0.0
# 1000094     Commercial     IFRS Constant   347.235175          0.0
# 1000095     Commercial     IFRS Constant   347.235175          0.0
# 1000096     Commercial     IFRS Constant     2.315000          0.0
# 1000097     Commercial     IFRS Constant     2.315000          0.0
#
# [1000098 rows x 53 columns]

# %%
edas.compute_monthly_claim_summary()
# Out:
#                   ClaimFrequency   TotalClaims  ClaimSeverity
# TransactionMonth
# 2013-10                        0  0.000000e+00       0.000000
# 2013-11                        2  5.058508e+04   25292.539473
# 2013-12                        3  9.283386e+03    3094.461988
# 2014-01                        2  1.243686e+04    6218.429822
# 2014-02                        6  6.298931e+04   10498.217837
# 2014-03                       12  3.227850e+05   26898.751799
# 2014-04                       20  3.068636e+05   15343.179606
# 2014-05                       28  5.180427e+05   18501.526308
# 2014-06                       28  5.045364e+05   18019.157016
# 2014-07                       27  4.289822e+05   15888.230402
# 2014-08                       51  6.934197e+05   13596.464912
# 2014-09                       48  9.089024e+05   18935.467694
# 2014-10                       93  1.764693e+06   18975.194895
# 2014-11                      179  3.794245e+06   21196.900014
# 2014-12                      206  6.237473e+06   30278.995647
# 2015-01                      250  5.494524e+06   21978.094542
# 2015-02                      287  6.267653e+06   21838.511860
# 2015-03                      329  7.474981e+06   22720.308149
# 2015-04                      340  9.076825e+06   26696.544977
# 2015-05                      297  6.963110e+06   23444.814344
# 2015-06                      297  6.204182e+06   20889.500409
# 2015-07                      261  6.751214e+06   25866.722120
# 2015-08                       22  1.019819e+06   46355.405101

# %%
monthly_summary = edas.compute_monthly_claim_summary()

# %%
edas.plot_claim_trends(monthly_summary)

# %% [markdown]
# ### Which vehicle makes/models are associated with the highest and lowest claim amounts?
#
# Which vehicle makes/models are associated with the highest and lowest claim amounts?
#
# We’ll use grouping and aggregation on the make, Model, and TotalClaims columns.

# %%
df2 = edas.preprocess_transaction_month()

# %%
# Get top and bottom vehicles by claims
top_vehicles, bottom_vehicles = edas.get_claim_by_vehicle()

# %%
# Display results
print("Top Vehicles by Total Claims:")
print(top_vehicles)
# Out:
# Top Vehicles by Total Claims:
#               make                             Model   TotalClaims
# 321         TOYOTA         QUANTUM 2.7 SESFIKILE 16s  1.203750e+07
# 320         TOYOTA         QUANTUM 2.7 SESFIKILE 15s  1.151173e+07
# 319         TOYOTA         QUANTUM 2.7 SESFIKILE 14s  9.967764e+06
# 315         TOYOTA    QUANTUM 2.5 D-4D SESFIKILE 16s  7.733236e+06
# 308         TOYOTA             HiACE SUPER 16 F/Lift  3.275205e+06
# 305         TOYOTA                      HiACE SIYAYA  1.727756e+06
# 313         TOYOTA          QUANTUM 2.5 D-4D 14 SEAT  1.339541e+06
# 45             CMC                       AMANDLA 2.2  1.106007e+06
# 259         TOYOTA                     AVANZA 1.5 SX  1.089785e+06
# 179  MERCEDES-BENZ  SPRINTER 515 CDi HI-ROOF F/C P/V  8.874161e+05

# %%
print("\nBottom Vehicles by Total Claims (Non-zero):")
print(bottom_vehicles)
# Out:
# Bottom Vehicles by Total Claims (Non-zero):
#                                     make                           Model  \
# 358                           VOLKSWAGEN                   CITI.COM 1.4i
# 47                                   CMC       SESBUYILE 2.5 TDi 16 SEAT
# 146                        MERCEDES-BENZ            C200K ESTATE CLASSIC
# 50                                  FIAT          DUCATO 2.3 JTD F/C C/C
# 287                               TOYOTA                    COROLLA 140i
# 346  TOYOTA                                           COROLLA 1.6 ESTEEM
# 180                        MERCEDES-BENZ    SPRINTER 518 CDI D/C F/C C/C
# 157                        MERCEDES-BENZ        SPRINTER 308 CDI F/C C/C
# 211                               NISSAN  ALMERA 1.6 LUXURY A/T (H16/27)
# 201  MERCEDES-BENZ                           SPRINTER 519 CDI XL F/C P/V
#
#      TotalClaims
# 358   570.500000
# 47    750.649123
# 146   850.000000
# 50    850.000000
# 287   850.000000
# 346   850.000000
# 180  1140.350877
# 157  1140.350877
# 211  1225.000000
# 201  1317.929825

# %%
# Plot the results using the plotting method
edas.plot_vehicle_claims(top_vehicles, title="Top 10 Vehicle Makes/Models by Total Claims")

# %%
edas.plot_vehicle_claims(bottom_vehicles, title="Bottom 10 Vehicle Makes/Models by Total Claims (Non-Zero)")

# %% [markdown]
# ## Univariate Analysis:
# ■	Distribution of Variables: Plot histograms for numerical columns and bar charts for categorical columns to understand distributions..

# %%
visualize = visualize(df1)

# %%
# Identify numerical and categorical columns
numeric_cols = ['TotalClaims', 'TotalPremium', 'CustomValueEstimate', 'CalculatedPremiumPerTerm', 'SumInsured']
categorical_cols = ['Gender', 'Province', 'VehicleType', 'make', 'Model', 'CoverCategory']

# %%
# Plot numeric distributions
visualize.plot_numeric_distributions(numeric_cols)

# %%
# Plot categorical distributions
visualize.plot_categorical_distributions(categorical_cols)

# %% [markdown]
# ### Bivariate or Multivariate Analysis:
# ■	Correlations and Associations: Explore relationships between the monthly changes TotalPremium and TotalClaims as a function of ZipCode, using scatter plots and correlation matrices.

# %%
# Aggregate by month and PostalCode
monthly_zip_summary = visualize.aggregate_by_month_zip()

# %%
visualize.plot_premium_vs_claims_scatter(monthly_zip_summary)

# %%
# Correlation matrix for main numeric columns
num_cols = ['TotalPremium', 'TotalClaims', 'CalculatedPremiumPerTerm', 'SumInsured', 'CustomValueEstimate']
visualize.correlation_matrix_plot(num_cols)
